# %%
#discrete distribution
# 1.Bernoulli distribution - (p(x=x) = p^x * (1-p)^(1-x))where x is 0 or 1
# 2.binomial distribution-ncxp^x * q^(n-x) where n is the number of trials, p is the probability of success, and q is the probability of failure (q = 1 - p).
# 3.poisson distribution-
#
# 4.continuous distribution-this discribution is defined the data can take any value in a range
# 5.uniform distribution
# 6.normal distribution
# 7.exponential distribution
# 
# statistics
# 1.mean - the average of the data set
# 2.median - the middle value of the data set when arranged in order eg:[1,2,2,3,2,3,4,5] the median is 3
# 3.mode - the value that appears most frequently in the data set eg:[1,2,2,3,2,3,4,5] the mode is 2
# 4.variance - the measure of how far a set of numbers are spread out from their average value eg:[1,2,2,3,2,3,4,5] the variance is 1.5
# 5.standard deviation - the square root of the variance, it measures the amount of variation
# 6.range - the difference between the maximum and minimum values in the data set eg:[1,2,2,3,2,3,4,5] the range is 4
# 7.interquartile range - the difference between the 75th percentile and the 25th percentile, it measures the spread of the middle 50% of the data
# #

# %%
pip install scipy
# Out:
# ...
#      ---------------------------------------- 0.0/60.8 kB ? eta -:--:--
#      ---------------------------------------- 0.0/60.8 kB ? eta -:--:--
#      ------ --------------------------------- 10.2/60.8 kB ? eta -:--:--
#      ------------------------------- ------ 51.2/60.8 kB 660.6 kB/s eta 0:00:01
#      ------------------------------- ------ 51.2/60.8 kB 660.6 kB/s eta 0:00:01
#      -------------------------------------- 60.8/60.8 kB 361.2 kB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/38.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/38.6 MB 991.0 kB/s eta 0:00:39
#    ---------------------------------------- 0.1/38.6 MB 1.1 MB/s eta 0:00:36
#    ---------------------------------------- 0.1/38.6 MB 1.1 MB/s eta 0:00:37
#    ---------------------------------------- 0.1/38.6 MB 1.1 MB/s eta 0:00:37
#    ---------------------------------------- 0.1/38.6 MB 514.3 kB/s eta 0:01:15
# ...

# %%
pip install scipy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 25.1.1
# [notice] To update, run: C:\Users\visha\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
pip install scipy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from IPython import get_ipython
get_ipython().kernel.do_shutdown(restart=True)
# Out:
# {'status': 'ok', 'restart': True}
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
pip install scipy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install matplotlib
# Out:
# ...
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    - -------------------------------------- 0.3/8.1 MB ? eta -:--:--
#    --- ------------------------------------ 0.8/8.1 MB 2.0 MB/s eta 0:00:04
#    ----- ---------------------------------- 1.0/8.1 MB 1.9 MB/s eta 0:00:04
#    ------- -------------------------------- 1.6/8.1 MB 2.0 MB/s eta 0:00:04
#    --------- ------------------------------ 1.8/8.1 MB 2.0 MB/s eta 0:00:04
#    ---------- ----------------------------- 2.1/8.1 MB 1.8 MB/s eta 0:00:04
#    ------------- -------------------------- 2.6/8.1 MB 1.8 MB/s eta 0:00:03
#    ------------- -------------------------- 2.6/8.1 MB 1.8 MB/s eta 0:00:03
#    -------------- ------------------------- 2.9/8.1 MB 1.6 MB/s eta 0:00:04
#    ---------------- ----------------------- 3.4/8.1 MB 1.6 MB/s eta 0:00:03
#    ------------------ --------------------- 3.7/8.1 MB 1.6 MB/s eta 0:00:03
#    ------------------- -------------------- 3.9/8.1 MB 1.6 MB/s eta 0:00:03
# ...

# %%
from scipy.stats import bernoulli
import matplotlib.pyplot as plt
p=0.5
x=[0,1]
pmf = bernoulli.pmf(p,x)
plt.scatter(x, pmf,color='red')
plt.title('Bernoulli Distribution PMF')
plt.xlabel("bernoulli'\s pmf value")
plt.ylabel('Probability')
plt.show()

# %%
#binomial distribution - nc^xp^xq^(n-x)
from scipy.stats import binom
import numpy as np
n,p=10,0.5
x=range(0,n+1) 
pmf=binom.pmf(x,n,p)
plt.scatter(x,pmf, color='blue')
plt.title('Binomial Distribution PMF')
plt.xlabel('Number of successes')
plt.ylabel('Probability')
plt.show()

# %%
#poission distribuction- (e^-lambda*lambda-k)/n!
#'''
# to calculate the average possible outcomes with in the interval of time (e^-lambda*lambda-k)/n!
# '''

from scipy.stats import poisson 
lam=5
k=np.arange(0,10)
pmf=poisson.pmf(lam,k)
plt.bar(k,pmf,color="#1A0EC8")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[12], line 10
#       8 k=np.arange(0,10)
#       9 pmf=poisson.pmf(lam,k)
# ---> 10 plt.bar(k,pmf,color="#1A0EC8")
#      11 plt.show()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\matplotlib\_api\__init__.py:218, in caching_module_getattr.<locals>.__getattr__(name)
#     216 if name in props:
#     217     return props[name].__get__(instance)
# --> 218 raise AttributeError(
#     219     f"module {cls.__module__!r} has no attribute {name!r}")
#
# AttributeError: module 'matplotlib' has no attribute 'bar'

# %%
#countinues distribution - infinite measurement 
# 1.uniform distribution - 1/b-a

from scipy.stats import uniform
a=2
b=5
x=np.linspace(a,b,200)
pdf=uniform.pdf(x,loc=a,scale=b-a) 
print(pmf)
plt.bar(x,pdf,color="red")
plt.show()
# Out:
# [0.         0.00306566 0.03608941 0.10081881 0.15629345 0.17546737
#  0.16062314 0.12771667 0.09160366 0.06072688]

# %%
#Exponential distribution - average rate (lambda.e^-lambda)
from scipy.stats import expon
lam=2
x=np.linspace(0,10,100)
pdf=expon.pdf(x,scale=1/lam)
plt.bar(x,pdf,color="green")
# Out:
# <BarContainer object of 100 artists>

# %%
x=[0,1,2]
a=0
p_x=[0.3,0.5,0.2]
for i in range(len(x)):
    a+=x[i]*p_x[i]
print(a)
# Out:
# 0.9

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[16], line 4
#       2 x=[0,1,2]
#       3 p_x=[0.3,0.5,0.2]
# ----> 4 E,V=np.mean_variance(x,p_x)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\__init__.py:808, in __getattr__(attr)
#     805     import numpy.char as char
#     806     return char.chararray
# --> 808 raise AttributeError(f"module {__name__!r} has no attribute {attr!r}")
#
# AttributeError: module 'numpy' has no attribute 'mean_variance'

# %%
def mean_var(x,y):
    e=sum(v*p for v,p in zip(x,y))
        
    e1=sum(v**2*p for v,p in zip(x,y))
        
    var=e1-e**2
    return e,var
x=[0,1,2]
p_x=[0.3,0.5,0.2]
E,V=mean_var(x,p_x)
print(E)
print(V)
# Out:
# 0.9
# 0.49

# %%
#central limit theorm 
#simulation parameter
import matplotlib.pyplot as plt
n_trial=1000
n_dice=30
sample=[]
for i in range(n_trial):
    r=np.random.randint(1,7,n_dice)
    sample.append(np.mean(r))
plt.hist(sample,bins=30,color="red",edgecolor="black",density=True)  
plt.title('Central Limit Theorem Simulation')
plt.xlabel('Sample Mean')   
plt.ylabel('Density')
plt.grid(True)
plt.axvline(x=3.5, color="blue", linestyle="--", label="expected mean(3.5)")
plt.legend()
plt.show()

# %%
num=1800
a=int(str(num)[::-1])
b=int(str(a)[::-1])
if b==num:
    print(True)
else:
    print( False)
# Out:
# False

# %%
n=7
c=0
for i in range(1,n+1):
    if i%3==0 or i%5==0 or i%7 ==0:
        c+=i
        print(c)
# Out:
# 3
# 8
# 14
# 21
